# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
BGO = pd.read_table(r'BGO.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
PWO = pd.read_table(r'PWO.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
LYSO = pd.read_table(r'LYSO.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
GAGG = pd.read_table(r'GAGG.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
# Out:
# /home/utente/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
# /home/utente/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#
# /home/utente/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/utente/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead.
#   after removing the cwd from sys.path.

# %%
fig = plt.figure(figsize=(7, 5))
plt.plot(BGO.wl, BGO.t, label='BGO (12 mm)')
plt.plot(PWO.wl, PWO.t, label='PWO (12 mm)')
plt.plot(LYSO.wl, LYSO.t, label='LYSO (12 mm)')
plt.plot(GAGG.wl, GAGG.t, label='GAGG (12 mm)')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Transmittance [%]', size=16)
plt.grid()
plt.title('FCC NA - Trans. measured @ photonics lab (UNINA)', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(200, 750, 50))
plt.savefig('transmittance.png', dpi=300, bbox_inches='tight')
plt.show()
