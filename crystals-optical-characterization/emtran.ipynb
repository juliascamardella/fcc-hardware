# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
sr=np.concatenate([np.arange(0, 20), np.arange(1180,1228)])

e_BGO = pd.read_table(r'emission/BGO.csv', skiprows=sr, sep=';', decimal=',', names=['wl', 'e'])
e_BSO = pd.read_table(r'emission/BSO.csv', skiprows=sr, sep=';', decimal=',', names=['wl', 'e'])
e_PWO = pd.read_table(r'emission/PWO_320_900nm.csv', skiprows=sr, sep=';', decimal=',', names=['wl', 'e'])
e_LYSO = pd.read_table(r'emission/LYSO_medium.csv', skiprows=sr, sep=';', decimal=',', names=['wl', 'e'])
e_GAGG = pd.read_table(r'emission/GAGG_medium_440nm.csv', skiprows=sr, sep=';', decimal=',', names=['wl', 'e'])
e_GAGG = pd.read_table(r'emission/GAGG_medium_300nm.csv', skiprows=sr, sep=';', decimal=',', names=['wl', 'e'])

# %%
t_BGO = pd.read_table(r'transmittance/BGO.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
t_PWO = pd.read_table(r'transmittance/PWO.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
t_LYSO = pd.read_table(r'transmittance/LYSO.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])
t_GAGG = pd.read_table(r'transmittance/GAGG.Sample.csv', skiprows=2,sep=',', names=['wl', 't'])

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Wavelenght [nm]', fontsize=14)
ax1.set_ylabel('Transmittance [%]', color=color, fontsize=14)
ax1.plot(t_BGO.wl, t_BGO.t, color=color, label='transmittance')
ax1.tick_params(axis='y', labelcolor=color)

#plt.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Emission intensity [a.u.]', color=color, fontsize=14)  # we already handled the x-label with ax1
ax2.plot(e_BGO.wl, e_BGO.e/e_BGO.e.max(), color=color, label='ex @ 300 nm')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(-0, 2)
ax1.set_ylim(-0, 100)
plt.legend()

ax2.annotate(r'BGO', xycoords='axes fraction', xy=(0.1, 0.9), ha='center', fontsize=16)# fontweight='bold')#, style='italic')

plt.title('FCC-NA Emission spectra meas. @ UNINA phot. lab', size=12)
ax1.grid()
ax1.set_xticks(np.arange(200, 901, 50))
ax1.set_xlim(200, 850)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.savefig('BGO.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Wavelenght [nm]', fontsize=14)
ax1.set_ylabel('Transmittance [%]', color=color, fontsize=14)
#ax1.plot(t_BSO.wl, t_BSO.t, color=color, label='transmittance')
ax1.tick_params(axis='y', labelcolor=color)

#plt.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Emission intensity [a.u.]', color=color, fontsize=14)  # we already handled the x-label with ax1
ax2.plot(e_BSO.wl, e_BSO.e/e_BSO.e.max(), color=color, label='ex @ 300 nm')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(-0, 2)
ax1.set_ylim(-0, 100)
plt.legend()

ax2.annotate(r'BSO', xycoords='axes fraction', xy=(0.1, 0.9), ha='center', fontsize=16)# fontweight='bold')#, style='italic')

plt.title('FCC-NA Emission spectra meas. @ UNINA phot. lab', size=12)
ax1.grid()
ax1.set_xticks(np.arange(200, 901, 50))
ax1.set_xlim(200, 850)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.savefig('BSO.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Wavelenght [nm]', fontsize=14)
ax1.set_ylabel('Transmittance [%]', color=color, fontsize=14)
ax1.plot((t_PWO.wl[:-1]+t_PWO.wl[1:])/2, (t_PWO.t[:-1]+t_PWO.t[1:])/2, color=color, label='transmittance')
ax1.tick_params(axis='y', labelcolor=color)

#plt.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Emission intensity [a.u.]', color=color, fontsize=14)  # we already handled the x-label with ax1
ax2.plot(e_PWO.wl, e_PWO.e/e_PWO.e.max(), color=color, label='ex @ 300 nm')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(-0, 2)
ax1.set_ylim(-0, 100)
plt.legend()

ax2.annotate(r'PWO', xycoords='axes fraction', xy=(0.1, 0.9), ha='center', fontsize=16)# fontweight='bold')#, style='italic')

plt.title('FCC-NA Emission spectra meas. @ UNINA phot. lab', size=12)
ax1.grid()
ax1.set_xticks(np.arange(200, 901, 50))
ax1.set_xlim(200, 850)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.savefig('PWO.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Wavelenght [nm]', fontsize=14)
ax1.set_ylabel('Transmittance [%]', color=color, fontsize=14)
ax1.plot((t_LYSO.wl[:-1]+t_LYSO.wl[1:])/2, (t_LYSO.t[:-1]+t_LYSO.t[1:])/2, color=color, label='transmittance')
ax1.tick_params(axis='y', labelcolor=color)

#plt.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Emission intensity [a.u.]', color=color, fontsize=14)  # we already handled the x-label with ax1
ax2.plot(e_LYSO.wl, e_LYSO.e/e_LYSO.e.max(), color=color, label='ex @ 300 nm')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(-0, 2)
ax1.set_ylim(-0, 100)
plt.legend()

ax2.annotate(r'LYSO', xycoords='axes fraction', xy=(0.1, 0.9), ha='center', fontsize=16)# fontweight='bold')#, style='italic')

plt.title('FCC-NA Emission spectra meas. @ UNINA phot. lab', size=12)
ax1.grid()
ax1.set_xticks(np.arange(200, 901, 50))
ax1.set_xlim(200, 850)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.savefig('LYSO.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Wavelenght [nm]', fontsize=14)
ax1.set_ylabel('Transmittance [%]', color=color, fontsize=14)
ax1.plot((t_GAGG.wl[:-1]+t_GAGG.wl[1:])/2, (t_GAGG.t[:-1]+t_GAGG.t[1:])/2, color=color, label='transmittance')
ax1.tick_params(axis='y', labelcolor=color)

#plt.legend()

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Emission intensity [a.u.]', color=color, fontsize=14)  # we already handled the x-label with ax1
ax2.plot(e_GAGG.wl, e_GAGG.e/e_GAGG.e.max(), color=color, label='ex @ 440 nm')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(-0, 2)
ax1.set_ylim(-0, 100)
plt.legend()

ax2.annotate(r'GAGG', xycoords='axes fraction', xy=(0.1, 0.9), ha='center', fontsize=16)# fontweight='bold')#, style='italic')

plt.title('FCC-NA Emission spectra meas. @ UNINA phot. lab', size=12)
ax1.grid()
ax1.set_xticks(np.arange(200, 901, 50))
ax1.set_xlim(200, 850)
fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.savefig('GAGG.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
fig = plt.figure(figsize=(7, 5))
plt.plot(BGO.wl, BGO.e/BGO.e.max(), label='BGO (ex: 300nm)')
plt.plot(BSO.wl, BSO.e/BSO.e.max(), label='BSO (ex: 300nm)')
plt.plot(PWO.wl, PWO.e/PWO.e.max(), label='PWO (ex: 300nm)')
plt.plot(LYSO.wl, LYSO.e/LYSO.e.max(), label='LYSO (ex: 300nm)')
plt.plot(GAGG.wl, GAGG.e/GAGG.e.max(), label='GAGG (ex: 420nm)')
plt.xlabel('Wavelenght [nm]', size=16)
plt.ylabel('Intensity [a.u.]', size=16)
plt.grid()
plt.title('FCC-NA Emission spectra meas. @ UNINA phot. lab', size=14)
plt.legend(fontsize=14, loc=4)
plt.xticks(np.arange(300, 901, 50))
plt.savefig('emission.png', dpi=300, bbox_inches='tight')
plt.show()
